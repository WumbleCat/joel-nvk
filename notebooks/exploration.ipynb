# %% [markdown]
# # Exploration
#
# Scratch space. Anything that earns its keep moves into `src/joel_nvk/`.

# %%
# %load_ext autoreload
# %autoreload 2

from joel_nvk.utils import load_config, outputs_dir

config = load_config("dev")
config

# %%
# Figures belong in outputs/figures/
outputs_dir() / "figures"
